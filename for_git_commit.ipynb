# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/NLP
# Out:
# /content/drive/MyDrive/NLP

# %%
# !git init
# !git config --global user.email 'bluesaurus2@gmail.com'
# !git config --global user.name 'saurus2'
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/NLP/.git/

# %%
# !git add .
# !git commit -m 'modifying files'
# Out:
# [main 8b10efb] modifying files
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
# !git remote add origin https://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@github.com/saurus2/NLP.git
#!git clone https://saurus2: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@github.com/saurus2/NLP.git
# Out:
# fatal: remote origin already exists.

# %%
# !git fetch
# Out:
# <content/drive/MyDrive/NLP/.git/MERGE_MSG" 7L, 291C▽  [>cMerge branch 'main' of https://github.com/saurus2/NLP into main
#
# # Please enter a commit message to explain why this merge is necessary,
# # especially if it merges an updated upstream into a topic branch.
# #
# # Lines starting with '#' will be ignored, and an empty message aborts
# # the commit.
# ...

# %%
# !git pull
# Out:
# error: You have not concluded your merge (MERGE_HEAD exists).
# hint: Please, commit your changes before merging.
# fatal: Exiting because of unfinished merge.

# %%
# !git push origin main
